# %%
import importlib
import final_forward_attenuation
importlib.reload(final_forward_attenuation)
from final_forward_attenuation import run_simulation, default_species, convert_atm, txt_to_npy, convert_vmr, plot_npy, plot_histogram

# %%
'''Convirtiendo .txts a .npys'''
txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
txt_to_npy('GT_PROFE_TXT/CO_4-10.txt','GT_PROFE/CO_4-10')
txt_to_npy('GT_PROFE_TXT/CO_10-30.txt','GT_PROFE/CO_10-30')
txt_to_npy('GT_PROFE_TXT/N2O_4-10.txt','GT_PROFE/N2O_4-10')
txt_to_npy('GT_PROFE_TXT/N2O_10-30.txt','GT_PROFE/N2O_10-30')
txt_to_npy('GT_PROFE_TXT/O3_4-10.txt','GT_PROFE/O3_4-10')
txt_to_npy('GT_PROFE_TXT/Transmittance_Standard_CO2_4-10_1m.txt','GT_PROFE/Transmittance_Standard_CO2_4-10_1m')
txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
# Out:
# Guardado como arreglo numpy en: GT_PROFE/CH4_10-30.npy
# Guardado como arreglo numpy en: GT_PROFE/CH4_10-30.npy
# Guardado como arreglo numpy en: GT_PROFE/CH4_10-30.npy
# Guardado como arreglo numpy en: GT_PROFE/CH4_10-30.npy
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 6
#       4 txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
#       5 txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
# ----> 6 txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
#       7 txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
#       8 txt_to_npy('GT_PROFE_TXT/CH4_10-30.txt','GT_PROFE/CH4_10-30')
#
# File c:\Users\PC\Documents\GitHub\Stand-off\final_forward_attenuation.py:48, in txt_to_npy(txt_path, out_path)
#      45 trans = []
#      47 with open(txt_path, "r") as f:
# ---> 48     for line in f:
# ...
