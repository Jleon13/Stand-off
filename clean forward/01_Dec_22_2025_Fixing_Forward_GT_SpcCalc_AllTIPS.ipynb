# %% [markdown]
# ### *Imports*

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## **We gonna plot the GT of all molecules - Professor Data**

# %%
data_GT_CO2 = np.load('/home/jleon13/Documents/AFOSR project/Py4catsForward/forwardOscar/Stand-off/GT_PROFE/Transmittance_Standard_CO2_4-10_1m.npy')

# %%
data_GT_CO2 = data_GT_CO2.T

# %%
data_GT_CO2.shape
# Out:
# (644299, 2)

# %%
first_column = data_GT_CO2[:, 0]
plt.plot(first_column)

# %%
plt.hist(first_column, bins=50, edgecolor='black', alpha=0.7)
plt.title('Histogram of First Column')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.grid(True, alpha=0.3)
plt.show()

# %% [markdown]
# ## ***We gonna plot the histograms of the GT***
